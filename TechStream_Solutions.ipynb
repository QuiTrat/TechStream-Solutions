# %%
# import needed library

import pandas as pd
import numpy as np

# %%
# Loading data

id_1='1by8tPHwOnq3uKYK2E7sA9VBUYoPM4p1Rnrm_Ss9cyHI'
id_2='1AZOIThOV4P-0eYDge53ZwumVkfkHoYPWxst3k3Bv87c'
id_3='10OGbaywwMIqKgnPGy8VDvpBVtjyqln47iYa2lFhI9Mw'
id_4='1c_WihqTZCQvNgxzmd-OwhR9i5diwtfxXVLyMn8R-Lp4'
id_5='1qayqML1zCKdmtzutkcy9LWvE6xFRm6TGBEVkHHJKIuE'

# %%
url_1='https://docs.google.com/spreadsheets/d/' + id_1 + '/export?format=xlsx'
url_2='https://docs.google.com/spreadsheets/d/' + id_2 + '/export?format=xlsx'
url_3='https://docs.google.com/spreadsheets/d/' + id_3 + '/export?format=xlsx'
url_4='https://docs.google.com/spreadsheets/d/' + id_4 + '/export?format=xlsx'
url_5='https://docs.google.com/spreadsheets/d/' + id_5 + '/export?format=xlsx'

# %%
df_customer_life=pd.read_excel(url_1, sheet_name='Sheet1')
df_marketing_expenses=pd.read_excel(url_2, sheet_name='Sheet1')
df_monthly_expenses=pd.read_excel(url_3, sheet_name='Sheet1')
df_payroll=pd.read_excel(url_4, sheet_name='Sheet1')
df_payment=pd.read_excel(url_5, sheet_name='Sheet1')

# %% [markdown]
# #**Data Explore and Calculation**

# %% [markdown]
# ####**Monthly expense**

# %%
df_monthly_expenses.head()
# Out:
#    #      month           category                  item  amount
# 0  1 2023-01-01       Server Costs           AWS Hosting    8000
# 1  2 2023-01-01       Server Costs  Google Cloud Storage    4000
# 2  3 2023-01-01  Software Licenses        Atlassian Jira    1200
# 3  4 2023-01-01  Software Licenses                 Slack     800
# 4  5 2023-01-01  Software Licenses            Salesforce    1500

# %%
df_monthly_expenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   #         27 non-null     int64
#  1   month     27 non-null     datetime64[ns]
#  2   category  27 non-null     object
#  3   item      27 non-null     object
#  4   amount    27 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 1.2+ KB

# %%
# Create new database for last month expenses:

cond = df_monthly_expenses['month'].dt.strftime('%Y-%m') == '2023-03'

df_last_month_expenses = df_monthly_expenses[cond]
df_last_month_expenses
# Out:
#      #      month           category                  item  amount
# 18  19 2023-03-01       Server Costs           AWS Hosting    8400
# 19  20 2023-03-01       Server Costs  Google Cloud Storage    4400
# 20  21 2023-03-01  Software Licenses        Atlassian Jira    1400
# 21  22 2023-03-01  Software Licenses                 Slack     900
# 22  23 2023-03-01  Software Licenses            Salesforce    1700
# 23  24 2023-03-01  Software Licenses                  Zoom     540
# 24  25 2023-03-01      Office Rental           Office Rent   10000
# 25  26 2023-03-01              Other       Office Supplies     600
# 26  27 2023-03-01              Other       Travel Expenses    3200

# %%
df_monthly_expenses['item'].unique()
# Out:
# array(['AWS Hosting', 'Google Cloud Storage', 'Atlassian Jira', 'Slack',
#        'Salesforce', 'Zoom', 'Office Rent', 'Office Supplies',
#        'Travel Expenses'], dtype=object)

# %%
# Calculate sales & marketing expenses

cond= df_last_month_expenses['item']=='Salesforce'
crm_cost = df_last_month_expenses[cond]['amount'].values[0]

crm_cost
# Out:
# 1700

# %%
# Add marketing & sales cost to total expenses:

Total_expenses = crm_cost
Total_expenses
# Out:
# 1700

# %%
type(df_last_month_expenses[cond]['amount'].values)
# Out:
# numpy.ndarray

# %% [markdown]
# ### **Last month Salary**

# %%
# explore dataset

df_payroll.head()
# Out:
#        month department  employee_name           position  paid  yyyy-mm
# 0 2023-01-01      Sales       John Doe      Sales Manager  1500  2023-01
# 1 2023-01-01      Sales     Jane Smith    Sales Associate   600  2023-01
# 2 2023-01-01      Sales      Jim Brown    Sales Associate   700  2023-01
# 3 2023-01-01      Sales   Laura Miller    Sales Associate   800  2023-01
# 4 2023-01-01  Marketing  Alice Johnson  Marketing Manager  1650  2023-01

# %%
df_payroll['yyyy-mm']=df_payroll['month'].dt.strftime('%Y-%m')
df_payroll
# Out:
#         month   department   employee_name            position  paid  yyyy-mm
# 0  2023-01-01        Sales        John Doe       Sales Manager  1500  2023-01
# 1  2023-01-01        Sales      Jane Smith     Sales Associate   600  2023-01
# 2  2023-01-01        Sales       Jim Brown     Sales Associate   700  2023-01
# 3  2023-01-01        Sales    Laura Miller     Sales Associate   800  2023-01
# 4  2023-01-01    Marketing   Alice Johnson   Marketing Manager  1650  2023-01
# 5  2023-01-01    Marketing       Bob Davis  Content Specialist   700  2023-01
# 6  2023-01-01  Engineering  Charlie Wilson    Senior Developer  2500  2023-01
# 7  2023-01-01  Engineering       Diana Lee           Developer  1700  2023-01
# 8  2023-01-01  Engineering       Eva White    Junior Developer  1000  2023-01
# 9  2023-01-01           HR     Frank Green          HR Manager  1300  2023-01
# 10 2023-01-01           HR      Gary Black       HR Specialist   700  2023-01
# 11 2023-01-01      Support    Hannah Scott        Support Lead   600  2023-01
# 12 2023-01-01      Support      Ian Harris  Support Specialist   500  2023-01
# 13 2023-01-01      Support     Emily Clark  Support Specialist   450  2023-01
# 14 2023-01-01    Analytics   Michael Brown   Analytics Manager  1700  2023-01
# 15 2023-01-01    Analytics    Sarah Wilson        Data Analyst  1200  2023-01
# 16 2023-01-01    Analytics       David Lee        Data Analyst  1300  2023-01
# 17 2023-02-01        Sales        John Doe       Sales Manager  1500  2023-02
# 18 2023-02-01        Sales      Jane Smith     Sales Associate   600  2023-02
# 19 2023-02-01        Sales       Jim Brown     Sales Associate   700  2023-02
# 20 2023-02-01        Sales    Laura Miller     Sales Associate  5100  2023-02
# 21 2023-02-01    Marketing   Alice Johnson   Marketing Manager  1650  2023-02
# 22 2023-02-01    Marketing       Bob Davis  Content Specialist   700  2023-02
# 23 2023-02-01  Engineering  Charlie Wilson    Senior Developer  2500  2023-02
# 24 2023-02-01  Engineering       Diana Lee           Developer  1700  2023-02
# 25 2023-02-01  Engineering       Eva White    Junior Developer  1000  2023-02
# 26 2023-02-01           HR     Frank Green          HR Manager  1300  2023-02
# 27 2023-02-01           HR      Gary Black       HR Specialist   700  2023-02
# 28 2023-02-01      Support    Hannah Scott        Support Lead   600  2023-02
# 29 2023-02-01      Support      Ian Harris  Support Specialist   500  2023-02
# 30 2023-02-01      Support     Emily Clark  Support Specialist   450  2023-02
# 31 2023-02-01    Analytics   Michael Brown   Analytics Manager  1700  2023-02
# 32 2023-02-01    Analytics    Sarah Wilson        Data Analyst  1200  2023-02
# 33 2023-02-01    Analytics       David Lee        Data Analyst  1300  2023-02
# 34 2023-03-01        Sales        John Doe       Sales Manager  1500  2023-03
# 35 2023-03-01        Sales      Jane Smith     Sales Associate   600  2023-03
# 36 2023-03-01        Sales       Jim Brown     Sales Associate   700  2023-03
# 37 2023-03-01        Sales    Laura Miller     Sales Associate   800  2023-03
# 38 2023-03-01    Marketing   Alice Johnson   Marketing Manager  1650  2023-03
# 39 2023-03-01    Marketing       Bob Davis  Content Specialist   700  2023-03
# 40 2023-03-01  Engineering  Charlie Wilson    Senior Developer  2500  2023-03
# 41 2023-03-01  Engineering       Diana Lee           Developer  1700  2023-03
# 42 2023-03-01  Engineering       Eva White    Junior Developer  1000  2023-03
# 43 2023-03-01           HR     Frank Green          HR Manager  1300  2023-03
# 44 2023-03-01           HR      Gary Black       HR Specialist   700  2023-03
# 45 2023-03-01      Support    Hannah Scott        Support Lead   600  2023-03
# 46 2023-03-01      Support      Ian Harris  Support Specialist   500  2023-03
# 47 2023-03-01      Support     Emily Clark  Support Specialist   450  2023-03
# 48 2023-03-01    Analytics   Michael Brown   Analytics Manager  1700  2023-03
# 49 2023-03-01    Analytics    Sarah Wilson        Data Analyst  1200  2023-03
# 50 2023-03-01    Analytics       David Lee        Data Analyst  1300  2023-03

# %%
# create function to get last_month data

def get_last_month(df_payroll,month):
  last_month=df_payroll['month'].max().strftime('%Y-%m')

  cond = df_payroll['month'].dt.strftime('%Y-%m') == last_month

  df_last_month_payroll = df_payroll[cond]
  return df_last_month_payroll

df_last_month_payroll = get_last_month(df_payroll,'month')
df_last_month_payroll
# Out:
#         month   department   employee_name            position  paid  yyyy-mm
# 34 2023-03-01        Sales        John Doe       Sales Manager  1500  2023-03
# 35 2023-03-01        Sales      Jane Smith     Sales Associate   600  2023-03
# 36 2023-03-01        Sales       Jim Brown     Sales Associate   700  2023-03
# 37 2023-03-01        Sales    Laura Miller     Sales Associate   800  2023-03
# 38 2023-03-01    Marketing   Alice Johnson   Marketing Manager  1650  2023-03
# 39 2023-03-01    Marketing       Bob Davis  Content Specialist   700  2023-03
# 40 2023-03-01  Engineering  Charlie Wilson    Senior Developer  2500  2023-03
# 41 2023-03-01  Engineering       Diana Lee           Developer  1700  2023-03
# 42 2023-03-01  Engineering       Eva White    Junior Developer  1000  2023-03
# 43 2023-03-01           HR     Frank Green          HR Manager  1300  2023-03
# 44 2023-03-01           HR      Gary Black       HR Specialist   700  2023-03
# 45 2023-03-01      Support    Hannah Scott        Support Lead   600  2023-03
# 46 2023-03-01      Support      Ian Harris  Support Specialist   500  2023-03
# 47 2023-03-01      Support     Emily Clark  Support Specialist   450  2023-03
# 48 2023-03-01    Analytics   Michael Brown   Analytics Manager  1700  2023-03
# 49 2023-03-01    Analytics    Sarah Wilson        Data Analyst  1200  2023-03
# 50 2023-03-01    Analytics       David Lee        Data Analyst  1300  2023-03

# %% [markdown]
# ### **Salary of Sales and Marketing specialist**

# %%
# Filter data for sales & marketing

last_month_Sales_MKT_payroll=df_last_month_payroll[(df_last_month_payroll['department']=='Sales') | (df_last_month_payroll['department']=='Marketing')]
last_month_Sales_MKT_payroll
# Out:
#         month department  employee_name            position  paid  yyyy-mm
# 34 2023-03-01      Sales       John Doe       Sales Manager  1500  2023-03
# 35 2023-03-01      Sales     Jane Smith     Sales Associate   600  2023-03
# 36 2023-03-01      Sales      Jim Brown     Sales Associate   700  2023-03
# 37 2023-03-01      Sales   Laura Miller     Sales Associate   800  2023-03
# 38 2023-03-01  Marketing  Alice Johnson   Marketing Manager  1650  2023-03
# 39 2023-03-01  Marketing      Bob Davis  Content Specialist   700  2023-03

# %%
# Calculate salary of sales & marketing

last_month_salary=last_month_Sales_MKT_payroll['paid'].sum()
last_month_salary
# Out:
# 5950

# %%
# Add salary of sales & marketing to total expenses

Total_expenses+=last_month_salary
Total_expenses
# Out:
# 7650

# %% [markdown]
# ### **Marketing expenses**

# %%
# Explore dataset

df_marketing_expenses.head()
# Out:
#         date       channel  spending
# 0 2023-01-01    Google Ads       784
# 1 2023-01-01  Facebook Ads       659
# 2 2023-01-01  LinkedIn Ads       729
# 3 2023-01-01   Twitter Ads       292
# 4 2023-01-02    Google Ads       935

# %%
# create function to get last_month data

def get_last_month(df, date_column):
    last_month = df[date_column].max().strftime('%Y-%m')
    cond = df[date_column].dt.strftime('%Y-%m') == last_month
    df_last_month = df[cond]
    return df_last_month

last_month_mkt_expense=get_last_month(df_marketing_expenses,'date')
last_month_mkt_expense
# Out:
#           date       channel  spending
# 236 2023-03-01    Google Ads       449
# 237 2023-03-01  Facebook Ads       229
# 238 2023-03-01  LinkedIn Ads       835
# 239 2023-03-01   Twitter Ads       986
# 240 2023-03-02    Google Ads       912
# ..         ...           ...       ...
# 355 2023-03-30   Twitter Ads       960
# 356 2023-03-31    Google Ads       143
# 357 2023-03-31  Facebook Ads       183
# 358 2023-03-31  LinkedIn Ads       533
# 359 2023-03-31   Twitter Ads       909
#
# [124 rows x 3 columns]

# %%
# Calculate for last month Marketing expenses

total_mkt_expense = last_month_mkt_expense['spending'].sum()
total_mkt_expense
# Out:
# 68830

# %%
# Add marketing expenses to total expenses

Total_expenses+=total_mkt_expense
Total_expenses
# Out:
# 76480

# %% [markdown]
# ###**Payment**

# %%
# Explore dataset

df_payment.head()
# Out:
#         date  customer_id  receipt_amount  new_customer
# 0 2023-01-01         2653              67             1
# 1 2023-01-01         2731             271             1
# 2 2023-01-01         1277             231             0
# 3 2023-01-01         2094             107             0
# 4 2023-01-01         1314             416             0

# %%
# get last month data

last_month_payment = get_last_month(df_payment,'date')
last_month_payment
# Out:
#           date  customer_id  receipt_amount  new_customer
# 618 2023-03-01         1062             103             0
# 619 2023-03-01         2243             157             0
# 620 2023-03-01         1166             372             0
# 621 2023-03-01         2406             426             1
# 622 2023-03-01         2761              41             1
# ..         ...          ...             ...           ...
# 924 2023-03-31         2079             358             0
# 925 2023-03-31         2089             375             0
# 926 2023-03-31         1355             249             0
# 927 2023-03-31         1062             111             0
# 928 2023-03-31         1590             271             0
#
# [311 rows x 4 columns]

# %%
# Calculate total customers in the last month
total_customers=last_month_payment['customer_id'].nunique()
total_customers
# Out:
# 292

# %%
# Get last month data for new customers

cond=df_payment['new_customer']==1
last_month_payments_from_new_customers=last_month_payment[cond]
last_month_payments_from_new_customers
# Out:
# <ipython-input-76-c70aed4243a9>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   last_month_payments_from_new_customers=last_month_payment[cond]
#           date  customer_id  receipt_amount  new_customer
# 621 2023-03-01         2406             426             1
# 622 2023-03-01         2761              41             1
# 625 2023-03-01         2844             252             1
# 627 2023-03-01         2679             323             1
# 633 2023-03-02         1475              40             1
# ..         ...          ...             ...           ...
# 912 2023-03-29         1746             262             1
# 913 2023-03-29         2269             484             1
# 914 2023-03-29         2935             478             1
# 919 2023-03-29         1297             496             1
# 920 2023-03-30         2151             482             1
#
# [63 rows x 4 columns]

# %%
# Calculate number of new customers:

Number_of_customers=last_month_payments_from_new_customers['customer_id'].nunique()
Number_of_customers
# Out:
# 63

# %%
# percentage of new customers

percentage_of_new_customers=Number_of_customers/total_customers
percentage_of_new_customers
# Out:
# 0.21575342465753425

# %% [markdown]
# ##**CAC**

# %%
# Calculate last month CAC for new customers:

CAC = Total_expenses/Number_of_customers
CAC
# Out:
# 1213.968253968254

# %% [markdown]
# ##**ARPU**

# %%
# Calculate total revenue for new customers

total_revenue_new_customers = last_month_payments_from_new_customers['receipt_amount'].sum()
total_revenue_new_customers
# Out:
# 17320

# %%
# Calculate ARPU

ARPU = total_revenue_new_customers/Number_of_customers
ARPU
# Out:
# 274.92063492063494

# %% [markdown]
# ##**COGS**

# %%
# get last month expense:

last_month_expense = get_last_month(df_monthly_expenses,'month')
last_month_expense
# Out:
#      #      month           category                  item  amount
# 18  19 2023-03-01       Server Costs           AWS Hosting    8400
# 19  20 2023-03-01       Server Costs  Google Cloud Storage    4400
# 20  21 2023-03-01  Software Licenses        Atlassian Jira    1400
# 21  22 2023-03-01  Software Licenses                 Slack     900
# 22  23 2023-03-01  Software Licenses            Salesforce    1700
# 23  24 2023-03-01  Software Licenses                  Zoom     540
# 24  25 2023-03-01      Office Rental           Office Rent   10000
# 25  26 2023-03-01              Other       Office Supplies     600
# 26  27 2023-03-01              Other       Travel Expenses    3200

# %%
# Calculate last month expenses related to product:

last_month_product_expense = last_month_expense[last_month_expense['item'].isin(['Atlassian Jira','Slack','AWS Hosting','Google Cloud Storage'])]
last_month_product_expense
# Out:
#      #      month           category                  item  amount
# 18  19 2023-03-01       Server Costs           AWS Hosting    8400
# 19  20 2023-03-01       Server Costs  Google Cloud Storage    4400
# 20  21 2023-03-01  Software Licenses        Atlassian Jira    1400
# 21  22 2023-03-01  Software Licenses                 Slack     900

# %%
# Calculate last month direct product cost

last_month_product_cost=last_month_product_expense['amount'].sum()
last_month_product_cost
# Out:
# 15100

# %%
# Calculate last month direct product cost of new customers

last_month_product_cost_new_customers=last_month_product_cost*percentage_of_new_customers
last_month_product_cost_new_customers
# Out:
# 3257.876712328767

# %%
# Number of employee for each department

department_employee_count = df_payroll.groupby('department')['employee_name'].nunique()
print(department_employee_count)
# Out:
# department
# Analytics      3
# Engineering    3
# HR             2
# Marketing      2
# Sales          4
# Support        3
# Name: employee_name, dtype: int64

# %%
# total employee

total_employees = df_payroll['employee_name'].nunique()
print(total_employees)
# Out:
# 17

# %%
# percentage of production employee

percentage_of_production_employee = (department_employee_count['Engineering'] + department_employee_count['Support'])/ total_employees
print(percentage_of_production_employee)
# Out:
# 0.35294117647058826

# %%
# Allocated others expenses to production cost

last_month_other_expense = last_month_expense[last_month_expense['item'].isin(['Zoom','Office Rent','Office Supplies','Travel Expenses'])]
last_month_other_expense = last_month_other_expense['amount'].sum()
last_month_other_production_cost = last_month_other_expense * percentage_of_production_employee
last_month_other_production_cost
# Out:
# 5061.176470588236

# %%
# Allocated others expenses to production cost of new customers

last_month_other_production_cost_new_customers = last_month_other_production_cost * percentage_of_new_customers
last_month_other_production_cost_new_customers
# Out:
# 1091.966156325544

# %%
# last mont total production cost of new customers:

last_month_total_production_cost_new_customers = last_month_product_cost_new_customers + last_month_other_production_cost_new_customers
last_month_total_production_cost_new_customers
# Out:
# 4349.842868654311

# %%
df_last_month_payroll.department.unique()
# Out:
# array(['Sales', 'Marketing', 'Engineering', 'HR', 'Support', 'Analytics'],
#       dtype=object)

# %%
df_last_month_payroll.head(10)
# Out:
#         month   department   employee_name            position  paid  yyyy-mm
# 34 2023-03-01        Sales        John Doe       Sales Manager  1500  2023-03
# 35 2023-03-01        Sales      Jane Smith     Sales Associate   600  2023-03
# 36 2023-03-01        Sales       Jim Brown     Sales Associate   700  2023-03
# 37 2023-03-01        Sales    Laura Miller     Sales Associate   800  2023-03
# 38 2023-03-01    Marketing   Alice Johnson   Marketing Manager  1650  2023-03
# 39 2023-03-01    Marketing       Bob Davis  Content Specialist   700  2023-03
# 40 2023-03-01  Engineering  Charlie Wilson    Senior Developer  2500  2023-03
# 41 2023-03-01  Engineering       Diana Lee           Developer  1700  2023-03
# 42 2023-03-01  Engineering       Eva White    Junior Developer  1000  2023-03
# 43 2023-03-01           HR     Frank Green          HR Manager  1300  2023-03

# %%
last_month_salary_product_cost=df_last_month_payroll[(df_last_month_payroll['department']=='Engineering')|(df_last_month_payroll['department']=='Support')]
last_month_salary_product_cost
# Out:
#         month   department   employee_name            position  paid  yyyy-mm
# 40 2023-03-01  Engineering  Charlie Wilson    Senior Developer  2500  2023-03
# 41 2023-03-01  Engineering       Diana Lee           Developer  1700  2023-03
# 42 2023-03-01  Engineering       Eva White    Junior Developer  1000  2023-03
# 45 2023-03-01      Support    Hannah Scott        Support Lead   600  2023-03
# 46 2023-03-01      Support      Ian Harris  Support Specialist   500  2023-03
# 47 2023-03-01      Support     Emily Clark  Support Specialist   450  2023-03

# %%
# Calculate last month labor cost

last_month_labor_cost=last_month_salary_product_cost['paid'].sum()
last_month_labor_cost
# Out:
# 6750

# %%
# Calculate last month labor cost of new customers

last_month_labor_cost_new_customers=last_month_labor_cost*percentage_of_new_customers
last_month_labor_cost_new_customers
# Out:
# 1456.3356164383563

# %%
# Calculate COGS of new customers

COGS_new_customers = last_month_total_production_cost_new_customers + last_month_labor_cost_new_customers
COGS_new_customers
# Out:
# 5806.178485092667

# %% [markdown]
# ##**Gross Margin**

# %%
# Calculate Gross Margin

Gross_margin_new_customers= (total_revenue_new_customers-COGS_new_customers)/total_revenue_new_customers
Gross_margin_new_customers
# Out:
# 0.6647702953179754

# %% [markdown]
# ##**LTV**

# %%
# Calculate customer's lifespan:

df_customer_life['customer_life'] = (df_customer_life['churn_date'] - df_customer_life['start_date']).dt.days

# %%
df_customer_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     100 non-null    int64
#  1   start_date     100 non-null    datetime64[ns]
#  2   churn_date     100 non-null    datetime64[ns]
#  3   customer_life  100 non-null    int64
# dtypes: datetime64[ns](2), int64(2)
# memory usage: 3.2 KB

# %%
df_customer_life.head()
# Out:
#    Unnamed: 0 start_date churn_date  customer_life
# 0        1000 2021-11-15 2022-09-14            303
# 1        1001 2022-04-15 2023-02-16            307
# 2        1002 2022-10-30 2023-02-04             97
# 3        1003 2021-08-22 2023-02-07            534
# 4        1004 2021-08-23 2022-02-02            163

# %%
# Calculate average customer life (month)

AVG_customer_life = df_customer_life['customer_life'].mean()/30
AVG_customer_life
# Out:
# 9.841333333333333

# %%
# Calculate LTV

LTV = ARPU * AVG_customer_life * Gross_margin_new_customers
LTV
# Out:
# 1798.5929439477466

# %% [markdown]
# ##**LTV/CAC ratio**

# %%
# Calculate LTV/CAC ratio

LTV_CAC_ratio = LTV / CAC

LTV_CAC_ratio
# Out:
# 1.4815815307100946

# %% [markdown]
# #**Result**

# %%
# CAC:
print(f'CAC: {CAC}')
# Out:
# CAC: 1213.968253968254

# %%
# ARPU:
print(f'ARPU: {ARPU}')
# Out:
# ARPU: 274.92063492063494

# %%
# COGS:
print(f'COGS: {COGS_new_customers}')
# Out:
# COGS: 5806.178485092667

# %%
# Gross Margin:
print(f'Gross Margin: {Gross_margin_new_customers}')
# Out:
# Gross Margin: 0.6647702953179754

# %%
# LTV
print(f'LTV: {LTV}')
# Out:
# LTV: 1798.5929439477466

# %%
# LTV/CAC ratio:
print(f'LTV/CAC ratio: {LTV_CAC_ratio}')
# Out:
# LTV/CAC ratio: 1.4815815307100946

# %% [markdown]
# #**Conclusion**
#
# **LTV/CAC ratio = 1.4816**
#
# The **LTV/CAC** ratio is **greater than 1**, indicates that TechStream Solutions is generating more revenue from customers than it costs to acquire them. This is a positive sign, suggesting profitability
# and sustainable growth.
#
# However, an ideal LTV/CAC ratio typically ranges from 3 to 5, indicating a healthy balance between customer acquisition costs and the value generated from customers. TechStream Solutions shoud try to improve this ratio to ideal range.
#
# The average customer lifespans of TechStream Solution is only 9.81 months, company should find solutions to improve this lifespan in order to imporve LTV and LTV/CAC ratio.
